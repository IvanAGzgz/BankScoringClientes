# %% [markdown]
# # CALIDAD DE DATOS

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
from janitor import clean_names

#Automcompletar rápido
# %config IPCompleter.greedy=True

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = r'C:\Users\iagzg\Desktop\D4FB\D4FB\EstructuraDirectorio\03_MACHINE_LEARNING\06-MACHINE LEARNING PROJECT FRAMEWORK\CASOS\04_BANK\\'

# %% [markdown]
# Sustituir el nombre_fichero_datos.

# %%
nombre_fichero_datos = 'trabajo.csv'

# %% [markdown]
# Cargar los datos.

# %%
ruta_completa = ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_fichero_datos

df = pd.read_csv(ruta_completa)
df
# Out:
#        Unnamed: 0  age          job  marital            education  default  \
# 0               1   57     services  married          high.school  unknown
# 1               3   40       admin.  married             basic.6y       no
# 2               6   59       admin.  married  professional.course       no
# 3               9   25     services   single          high.school       no
# 4              10   41  blue-collar  married              unknown  unknown
# ...           ...  ...          ...      ...                  ...      ...
# 28827       41181   37       admin.  married    university.degree       no
# 28828       41182   29   unemployed   single             basic.4y       no
# 28829       41184   46  blue-collar  married  professional.course       no
# 28830       41186   44   technician  married  professional.course       no
# 28831       41187   74      retired  married  professional.course       no
#
#       housing loan    contact month  ... campaign  pdays  previous  \
# 0          no   no  telephone   may  ...        1    999         0
# 1          no   no  telephone   may  ...        1    999         0
# 2          no   no  telephone   may  ...        1    999         0
# 3         yes   no  telephone   may  ...        1    999         0
# 4          no   no  telephone   may  ...        1    999         0
# ...       ...  ...        ...   ...  ...      ...    ...       ...
# 28827     yes   no   cellular   nov  ...        1    999         0
# 28828     yes   no   cellular   nov  ...        1      9         1
# 28829      no   no   cellular   nov  ...        1    999         0
# 28830      no   no   cellular   nov  ...        1    999         0
# 28831     yes   no   cellular   nov  ...        3    999         1
#
#           poutcome  emp.var.rate cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent           1.1         93.994          -36.4      4.857
# 1      nonexistent           1.1         93.994          -36.4      4.857
# 2      nonexistent           1.1         93.994          -36.4      4.857
# 3      nonexistent           1.1         93.994          -36.4      4.857
# 4      nonexistent           1.1         93.994          -36.4      4.857
# ...            ...           ...            ...            ...        ...
# 28827  nonexistent          -1.1         94.767          -50.8      1.028
# 28828      success          -1.1         94.767          -50.8      1.028
# 28829  nonexistent          -1.1         94.767          -50.8      1.028
# 28830  nonexistent          -1.1         94.767          -50.8      1.028
# 28831      failure          -1.1         94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 28827       4963.6  yes
# 28828       4963.6   no
# 28829       4963.6   no
# 28830       4963.6  yes
# 28831       4963.6   no
#
# [28832 rows x 22 columns]

# %% [markdown]
# La target es "y", indica si el cliente ha contratado fondos o no.

# %% [markdown]
# ## CORRECCIÓN DE NOMBRES DE VARIABLES

# %% [markdown]
# ### Corrección manual

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28832 entries, 0 to 28831
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      28832 non-null  int64
#  1   age             28832 non-null  int64
#  2   job             28832 non-null  object
#  3   marital         28832 non-null  object
#  4   education       28832 non-null  object
#  5   default         28832 non-null  object
#  6   housing         28832 non-null  object
#  7   loan            28832 non-null  object
#  8   contact         28832 non-null  object
#  9   month           28832 non-null  object
#  10  day_of_week     28832 non-null  object
#  11  duration        28832 non-null  int64
#  12  campaign        28832 non-null  int64
#  13  pdays           28832 non-null  int64
#  14  previous        28832 non-null  int64
#  15  poutcome        28832 non-null  object
#  16  emp.var.rate    28832 non-null  float64
#  17  cons.price.idx  28832 non-null  float64
#  18  cons.conf.idx   28832 non-null  float64
#  19  euribor3m       28832 non-null  float64
#  20  nr.employed     28832 non-null  float64
#  21  y               28832 non-null  object
# dtypes: float64(5), int64(6), object(11)
# memory usage: 4.8+ MB

# %%
df.head()
# Out:
#    Unnamed: 0  age          job  marital            education  default  \
# 0           1   57     services  married          high.school  unknown
# 1           3   40       admin.  married             basic.6y       no
# 2           6   59       admin.  married  professional.course       no
# 3           9   25     services   single          high.school       no
# 4          10   41  blue-collar  married              unknown  unknown
#
#   housing loan    contact month  ... campaign  pdays  previous     poutcome  \
# 0      no   no  telephone   may  ...        1    999         0  nonexistent
# 1      no   no  telephone   may  ...        1    999         0  nonexistent
# 2      no   no  telephone   may  ...        1    999         0  nonexistent
# 3     yes   no  telephone   may  ...        1    999         0  nonexistent
# 4      no   no  telephone   may  ...        1    999         0  nonexistent
#
#    emp.var.rate cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0           1.1         93.994          -36.4      4.857       5191.0  no
# 1           1.1         93.994          -36.4      4.857       5191.0  no
# 2           1.1         93.994          -36.4      4.857       5191.0  no
# 3           1.1         93.994          -36.4      4.857       5191.0  no
# 4           1.1         93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 22 columns]

# %%
#Eliminamos las variables que no vamos a usar.
df.drop(['Unnamed: 0','cons.conf.idx','nr.employed','cons.price.idx','duration'], axis = 1, inplace = True)

# %%
#Traducimos al español todas las variables.

df.rename(columns = {'age':'edad',
                     'job':'trabajo',
                     'marital':'estado',
                     'education':'educacion',
                     'default':'impagos',
                     'housing':'prestamo_hipotecario',
                     'loan':'prestamo_personal',
                     'contact':'canal_contacto',
                     'month':'mes',
                     'day_of_week':'dia_semana',
                     'campaign':'num_contactos_esta_semana',
                     'pdays':'num_dias_ultimo_contacto',
                     'previous':'num_contactos_otras_campañas',
                     'poutcome':'resultado_campana_anterior',
                     'emp.var.rate':'variacion_tasa_empleo'
                    }, inplace=True)
df
# Out:
#        edad      trabajo   estado            educacion  impagos  \
# 0        57     services  married          high.school  unknown
# 1        40       admin.  married             basic.6y       no
# 2        59       admin.  married  professional.course       no
# 3        25     services   single          high.school       no
# 4        41  blue-collar  married              unknown  unknown
# ...     ...          ...      ...                  ...      ...
# 28827    37       admin.  married    university.degree       no
# 28828    29   unemployed   single             basic.4y       no
# 28829    46  blue-collar  married  professional.course       no
# 28830    44   technician  married  professional.course       no
# 28831    74      retired  married  professional.course       no
#
#       prestamo_hipotecario prestamo_personal canal_contacto  mes dia_semana  \
# 0                       no                no      telephone  may        mon
# 1                       no                no      telephone  may        mon
# 2                       no                no      telephone  may        mon
# 3                      yes                no      telephone  may        mon
# 4                       no                no      telephone  may        mon
# ...                    ...               ...            ...  ...        ...
# 28827                  yes                no       cellular  nov        fri
# 28828                  yes                no       cellular  nov        fri
# 28829                   no                no       cellular  nov        fri
# 28830                   no                no       cellular  nov        fri
# 28831                  yes                no       cellular  nov        fri
#
#        num_contactos_esta_semana  num_dias_ultimo_contacto  \
# 0                              1                       999
# 1                              1                       999
# 2                              1                       999
# 3                              1                       999
# 4                              1                       999
# ...                          ...                       ...
# 28827                          1                       999
# 28828                          1                         9
# 28829                          1                       999
# 28830                          1                       999
# 28831                          3                       999
#
#        num_contactos_otras_campañas resultado_campana_anterior  \
# 0                                 0                nonexistent
# 1                                 0                nonexistent
# 2                                 0                nonexistent
# 3                                 0                nonexistent
# 4                                 0                nonexistent
# ...                             ...                        ...
# 28827                             0                nonexistent
# 28828                             1                    success
# 28829                             0                nonexistent
# 28830                             0                nonexistent
# 28831                             1                    failure
#
#        variacion_tasa_empleo  euribor3m    y
# 0                        1.1      4.857   no
# 1                        1.1      4.857   no
# 2                        1.1      4.857   no
# 3                        1.1      4.857   no
# 4                        1.1      4.857   no
# ...                      ...        ...  ...
# 28827                   -1.1      1.028  yes
# 28828                   -1.1      1.028   no
# 28829                   -1.1      1.028   no
# 28830                   -1.1      1.028  yes
# 28831                   -1.1      1.028   no
#
# [28832 rows x 17 columns]

# %% [markdown]
# ## VISIÓN GENERAL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28832 entries, 0 to 28831
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   edad                          28832 non-null  int64
#  1   trabajo                       28832 non-null  object
#  2   estado                        28832 non-null  object
#  3   educacion                     28832 non-null  object
#  4   impagos                       28832 non-null  object
#  5   prestamo_hipotecario          28832 non-null  object
#  6   prestamo_personal             28832 non-null  object
#  7   canal_contacto                28832 non-null  object
#  8   mes                           28832 non-null  object
#  9   dia_semana                    28832 non-null  object
#  10  num_contactos_esta_semana     28832 non-null  int64
#  11  num_dias_ultimo_contacto      28832 non-null  int64
#  12  num_contactos_otras_campañas  28832 non-null  int64
#  13  resultado_campana_anterior    28832 non-null  object
#  14  variacion_tasa_empleo         28832 non-null  float64
#  15  euribor3m                     28832 non-null  float64
#  16  y                             28832 non-null  object
# dtypes: float64(2), int64(4), object(11)
# memory usage: 3.7+ MB

# %% [markdown]
# ## TIPOS DE DATOS

# %% [markdown]
# ### Identificación

# %%
df.dtypes
# Out:
# edad                              int64
# trabajo                          object
# estado                           object
# educacion                        object
# impagos                          object
# prestamo_hipotecario             object
# prestamo_personal                object
# canal_contacto                   object
# mes                              object
# dia_semana                       object
# num_contactos_esta_semana         int64
# num_dias_ultimo_contacto          int64
# num_contactos_otras_campañas      int64
# resultado_campana_anterior       object
# variacion_tasa_empleo           float64
# euribor3m                       float64
# y                                object
# dtype: object

# %% [markdown]
# ### Corrección

# %%
df = df.astype({'edad':'Int64',
           'euribor3m': 'float'})

df.dtypes
# Out:
# edad                              Int64
# trabajo                          object
# estado                           object
# educacion                        object
# impagos                          object
# prestamo_hipotecario             object
# prestamo_personal                object
# canal_contacto                   object
# mes                              object
# dia_semana                       object
# num_contactos_esta_semana         int64
# num_dias_ultimo_contacto          int64
# num_contactos_otras_campañas      int64
# resultado_campana_anterior       object
# variacion_tasa_empleo           float64
# euribor3m                       float64
# y                                object
# dtype: object

# %% [markdown]
# ## VALORES ÚNICOS

# %% [markdown]
# ### Identificación

# %%
df.nunique().sort_values()
# Out:
# y                                 2
# canal_contacto                    2
# impagos                           3
# prestamo_hipotecario              3
# prestamo_personal                 3
# resultado_campana_anterior        3
# estado                            4
# dia_semana                        5
# educacion                         8
# num_contactos_otras_campañas      8
# variacion_tasa_empleo            10
# mes                              10
# trabajo                          12
# num_dias_ultimo_contacto         25
# num_contactos_esta_semana        42
# edad                             75
# euribor3m                       310
# dtype: int64

# %% [markdown]
# ## DUPLICADOS

# %% [markdown]
# ### Identificación

# %%
df.duplicated().sum()
# Out:
# 892

# %% [markdown]
# ### Corrección

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# ## SEPARAR NUMÉRICAS Y CATEGÓRICAS

# %% [markdown]
# ### Categóricas

# %%
cat = df.select_dtypes(exclude = 'number').copy()

# %% [markdown]
# ### Numéricas

# %%
num = df.select_dtypes(include='number').copy()

# %% [markdown]
# ## GESTIÓN DE CATEGÓRICAS

# %% [markdown]
# ### Nulos

# %% [markdown]
# #### Identificación

# %%
cat.isna().sum().sort_values(ascending = False)
# Out:
# trabajo                       0
# estado                        0
# educacion                     0
# impagos                       0
# prestamo_hipotecario          0
# prestamo_personal             0
# canal_contacto                0
# mes                           0
# dia_semana                    0
# resultado_campana_anterior    0
# y                             0
# dtype: int64

# %% [markdown]
# ## GESTIÓN DE NUMÉRICAS

# %% [markdown]
# ### Nulos

# %% [markdown]
# #### Identificación

# %%
num.isna().sum().sort_values(ascending = False)
# Out:
# edad                            0
# num_contactos_esta_semana       0
# num_dias_ultimo_contacto        0
# num_contactos_otras_campañas    0
# variacion_tasa_empleo           0
# euribor3m                       0
# dtype: int64

# %% [markdown]
# ### Atípicos

# %% [markdown]
# #### Por desviación típica

# %% [markdown]
# ##### Identificación

# %% [markdown]
# ###### Definir el número de desviaciones típicas

# %%
num_desv_tip = 4

# %% [markdown]
# ###### Función que devuelve los índices de los atípicos

# %%
def atipicos_desv_tip(variable, num_desv_tip = 4):
    #sacamos los nulos por ahora
    variable = variable.dropna()
    #calculamos los límites
    media = np.mean(variable)
    sd = np.std(variable)
    umbral = sd * num_desv_tip
    lim_inf = media - umbral
    lim_sup = media + umbral
    #encontramos los índices de los que están fuera de los límites
    indices = [indice for indice,valor in variable.items() if valor < lim_inf or valor > lim_sup]
    return(indices)

# %% [markdown]
# ###### Función que cuenta el número de atípicos

# %%
def conteo_atipicos(df,variable, num_desv_tip = 4):
    atipicos = atipicos_desv_tip(df[variable], num_desv_tip)
    return(df.loc[atipicos,variable].value_counts())

# %%
df
# Out:
#        edad      trabajo   estado            educacion  impagos  \
# 0        57     services  married          high.school  unknown
# 1        40       admin.  married             basic.6y       no
# 2        59       admin.  married  professional.course       no
# 3        25     services   single          high.school       no
# 4        41  blue-collar  married              unknown  unknown
# ...     ...          ...      ...                  ...      ...
# 28827    37       admin.  married    university.degree       no
# 28828    29   unemployed   single             basic.4y       no
# 28829    46  blue-collar  married  professional.course       no
# 28830    44   technician  married  professional.course       no
# 28831    74      retired  married  professional.course       no
#
#       prestamo_hipotecario prestamo_personal canal_contacto  mes dia_semana  \
# 0                       no                no      telephone  may        mon
# 1                       no                no      telephone  may        mon
# 2                       no                no      telephone  may        mon
# 3                      yes                no      telephone  may        mon
# 4                       no                no      telephone  may        mon
# ...                    ...               ...            ...  ...        ...
# 28827                  yes                no       cellular  nov        fri
# 28828                  yes                no       cellular  nov        fri
# 28829                   no                no       cellular  nov        fri
# 28830                   no                no       cellular  nov        fri
# 28831                  yes                no       cellular  nov        fri
#
#        num_contactos_esta_semana  num_dias_ultimo_contacto  \
# 0                              1                       999
# 1                              1                       999
# 2                              1                       999
# 3                              1                       999
# 4                              1                       999
# ...                          ...                       ...
# 28827                          1                       999
# 28828                          1                         9
# 28829                          1                       999
# 28830                          1                       999
# 28831                          3                       999
#
#        num_contactos_otras_campañas resultado_campana_anterior  \
# 0                                 0                nonexistent
# 1                                 0                nonexistent
# 2                                 0                nonexistent
# 3                                 0                nonexistent
# 4                                 0                nonexistent
# ...                             ...                        ...
# 28827                             0                nonexistent
# 28828                             1                    success
# 28829                             0                nonexistent
# 28830                             0                nonexistent
# 28831                             1                    failure
#
#        variacion_tasa_empleo  euribor3m    y
# 0                        1.1      4.857   no
# 1                        1.1      4.857   no
# 2                        1.1      4.857   no
# 3                        1.1      4.857   no
# 4                        1.1      4.857   no
# ...                      ...        ...  ...
# 28827                   -1.1      1.028  yes
# 28828                   -1.1      1.028   no
# 28829                   -1.1      1.028   no
# 28830                   -1.1      1.028  yes
# 28831                   -1.1      1.028   no
#
# [27940 rows x 17 columns]

# %% [markdown]
# ###### Variables a aplicar

# %%
var_atipicos_dt = num.columns.to_list()
var_atipicos_dt
# Out:
# ['edad',
#  'num_contactos_esta_semana',
#  'num_dias_ultimo_contacto',
#  'num_contactos_otras_campañas',
#  'variacion_tasa_empleo',
#  'euribor3m']

# %% [markdown]
# ###### Aplicar

# %%
for variable in var_atipicos_dt:
    print('\n' + variable + ':\n')
    print(conteo_atipicos(num,variable,num_desv_tip))
# Out:
# edad:
#
# edad
# 88    17
# 83    12
# 82     9
# 85     9
# 86     5
# 84     5
# 92     4
# 89     2
# 95     1
# 98     1
# Name: count, dtype: Int64
#
# num_contactos_esta_semana:
#
# num_contactos_esta_semana
# 14    54
# 17    41
# 15    33
# 16    33
# 18    20
# 21    18
# 20    15
# 19    15
# 24    13
# 22    12
# 23     9
# 27     8
# 29     7
# 31     6
# 25     5
# 28     4
# 30     4
# 32     4
# 26     3
# 33     3
# 34     3
# 35     2
# 40     2
# 43     2
# 42     1
# 39     1
# 41     1
# 56     1
# 37     1
# Name: count, dtype: int64
#
# num_dias_ultimo_contacto:
#
# num_dias_ultimo_contacto
# 3     302
# 6     286
# 4      71
# 9      45
# 12     44
# 2      43
# 10     37
# 7      36
# 5      29
# 13     27
# 11     19
# 1      18
# 15     16
# 14     15
# 8      14
# 0       8
# 16      6
# 17      3
# 18      3
# 22      3
# 19      2
# 21      1
# 26      1
# 20      1
# Name: count, dtype: int64
#
# num_contactos_otras_campañas:
#
# num_contactos_otras_campañas
# 3    156
# 4     49
# 5     11
# 6      3
# 7      1
# Name: count, dtype: int64
#
# variacion_tasa_empleo:
#
# Series([], Name: count, dtype: int64)
#
# euribor3m:
#
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ##### Corrección

# %% [markdown]
# Eliminar los registros que tengan al menos un atípico en alguna de las variables indicadas.

# %% [markdown]
# *Cuidado: Si se eliminan registros hay que eliminarlos tanto de cat como de num*

# %% [markdown]
# ###### Variables a aplicar

# %% [markdown]
# ###### Aplicar

# %%
for variable in var_atipicos_dt:
    cat.drop(atipicos_desv_tip(num[variable], num_desv_tip),axis = 0, inplace = True)
    num.drop(atipicos_desv_tip(num[variable], num_desv_tip),axis = 0, inplace = True)

# %%
cat
# Out:
#            trabajo   estado            educacion  impagos  \
# 0         services  married          high.school  unknown
# 1           admin.  married             basic.6y       no
# 2           admin.  married  professional.course       no
# 3         services   single          high.school       no
# 4      blue-collar  married              unknown  unknown
# ...            ...      ...                  ...      ...
# 28826       admin.  married    university.degree       no
# 28827       admin.  married    university.degree       no
# 28829  blue-collar  married  professional.course       no
# 28830   technician  married  professional.course       no
# 28831      retired  married  professional.course       no
#
#       prestamo_hipotecario prestamo_personal canal_contacto  mes dia_semana  \
# 0                       no                no      telephone  may        mon
# 1                       no                no      telephone  may        mon
# 2                       no                no      telephone  may        mon
# 3                      yes                no      telephone  may        mon
# 4                       no                no      telephone  may        mon
# ...                    ...               ...            ...  ...        ...
# 28826                   no                no       cellular  nov        fri
# 28827                  yes                no       cellular  nov        fri
# 28829                   no                no       cellular  nov        fri
# 28830                   no                no       cellular  nov        fri
# 28831                  yes                no       cellular  nov        fri
#
#       resultado_campana_anterior    y
# 0                    nonexistent   no
# 1                    nonexistent   no
# 2                    nonexistent   no
# 3                    nonexistent   no
# 4                    nonexistent   no
# ...                          ...  ...
# 28826                nonexistent   no
# 28827                nonexistent  yes
# 28829                nonexistent   no
# 28830                nonexistent  yes
# 28831                    failure   no
#
# [26256 rows x 11 columns]

# %%
num
# Out:
#        edad  num_contactos_esta_semana  num_dias_ultimo_contacto  \
# 0        57                          1                       999
# 1        40                          1                       999
# 2        59                          1                       999
# 3        25                          1                       999
# 4        41                          1                       999
# ...     ...                        ...                       ...
# 28826    36                          2                       999
# 28827    37                          1                       999
# 28829    46                          1                       999
# 28830    44                          1                       999
# 28831    74                          3                       999
#
#        num_contactos_otras_campañas  variacion_tasa_empleo  euribor3m
# 0                                 0                    1.1      4.857
# 1                                 0                    1.1      4.857
# 2                                 0                    1.1      4.857
# 3                                 0                    1.1      4.857
# 4                                 0                    1.1      4.857
# ...                             ...                    ...        ...
# 28826                             0                   -1.1      1.028
# 28827                             0                   -1.1      1.028
# 28829                             0                   -1.1      1.028
# 28830                             0                   -1.1      1.028
# 28831                             1                   -1.1      1.028
#
# [26256 rows x 6 columns]

# %% [markdown]
# ## GUARDAR DATASETS TRAS CALIDAD DE DATOS

# %% [markdown]
# Guardamos los avances en df, cat y num con un sufijo para poder guardar o recuperar avances del proyecto.
#
# En formato pickle para no perder las modificaciones de metadatos.

# %% [markdown]
# ### Definir los nombres de los archivos

# %%
ruta_trabajo = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'trabajo_resultado_calidad.pickle'
ruta_cat = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'cat_resultado_calidad.pickle'
ruta_num = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'num_resultado_calidad.pickle'

# %% [markdown]
# ### Guardar los archivos

# %%
df.to_pickle(ruta_trabajo)
cat.to_pickle(ruta_cat)
num.to_pickle(ruta_num)
